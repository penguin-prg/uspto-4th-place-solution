# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
aps = []
for n in range(1, 51):
    ap = np.mean([min(n, i) / i for i in range(1, 51)])
    aps.append(ap)

plt.plot(aps)
plt.grid()
plt.show()
